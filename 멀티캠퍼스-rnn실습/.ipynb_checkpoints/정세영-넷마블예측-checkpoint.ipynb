# %% [markdown]
# # 상장법인목록

# %%
import pandas as pd

# %%
df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download', header=0)[0]

# %%
df
# Out:
#            회사명    종목코드  ...                      홈페이지       지역
# 0         JS전선    5560  ...  http://www.jscable.co.kr     충청남도
# 1        거북선2호  101380  ...                       NaN    부산광역시
# 2        거북선6호  114140  ...                       NaN  제주특별자치도
# 3        교보메리츠   64900  ...                       NaN    서울특별시
# 4       국제관광공사   28780  ...                       NaN      NaN
# ...        ...     ...  ...                       ...      ...
# 3874        툴젠  199800  ...    http://www.toolgen.com    서울특별시
# 3875  플럼라인생명과학  222670  ...     http://www.plsdna.com    서울특별시
# 3876   피엔에이치테크  239890  ...   http://www.phtech.co.kr      경기도
# 3877  한국미라클피플사  331660  ...     http://www.kmpc.co.kr      경기도
# 3878       휴벡셀  212310  ...        http://huvexel.com      경기도
#
# [3879 rows x 9 columns]

# %%
df.shape
# Out:
# (3879, 9)

# %%
list(df['회사명'])[100:200]
# Out:
# ['굿라이프10-MF',
#  '글로웍스',
#  '네이쳐글로벌',
#  '넷컴스토리지',
#  '뉴젠아이씨티',
#  '뉴켐진스템셀',
#  '다임알짜2호-MF',
#  '단암산업',
#  '대백쇼핑',
#  '대신증권그로쓰스팩',
#  '데코',
#  '동방티엔씨',
#  '동아일렉콤',
#  '동원뮤추얼장보고1호',
#  '드림라인',
#  '마이다스코코',
#  '맥시스템',
#  '모빌탑',
#  '무한투자',
#  '미래아이티2',
#  '미래에셋알바트로스이',
#  '미래에셋크린채권형이',
#  '미래주식1',
#  '미래하이2호',
#  '미래하이4',
#  '미래한아름2',
#  '미주실업',
#  '박현주1호',
#  '박현주3성장',
#  '박현주7성장',
#  '베스트플로우',
#  '부산방직',
#  '비엔디',
#  '비엔씨컴퍼니',
#  '사라콤',
#  '사이노젠',
#  '삼능건설',
#  '삼성라이프에머랄드일',
#  '삼성프라임증권투자회',
#  '성보섬유',
#  '세븐코스프',
#  '세원',
#  '세이플러스',
#  '스틸플라워',
#  '승화프리텍',
#  '신텍',
#  '신한제4호스팩',
#  '신호테크',
#  '실크자산2',
#  '심스밸리',
#  '알루코',
#  '알에스넷',
#  '에이프로테크놀로지',
#  '엘앤피아너스',
#  '엠제이비',
#  '영일케미컬',
#  '우전',
#  '원진',
#  '유티엑스',
#  '이글5호',
#  '이랜드리테일',
#  '이레전자산업',
#  '이론테크',
#  '이롬텍',
#  '이앤텍',
#  '익산',
#  '일신',
#  '제네시스',
#  '조이토토',
#  '중앙디자인',
#  '지노시스템',
#  '지디코프',
#  '지앤알',
#  '지에스엔텍',
#  '지엔텍홀딩스',
#  '챌린지성장2',
#  '카카오M',
#  '태평양금속',
#  '트라이콤',
#  '트윈스챌린지펀드',
#  '파티게임즈',
#  '팬텀엔터그룹',
#  '퓨쳐인포넷',
#  '플래닛82',
#  '플래티넘성2-MF',
#  '하림홀딩스',
#  '한국4호스팩',
#  '한국제5호스팩',
#  '한국제6호스팩',
#  '한국종합철관',
#  '한국체인',
#  '한국화이바',
#  '한림창투',
#  '한아시스템',
#  '한일제관',
#  '한컴지엠디',
#  '한통엠닷컴',
#  '희훈디앤지',
#  '극동자동화',
#  '나무기술']

# %%
df2 = df.set_index('회사명')[['종목코드']]

# %%
import pandas_datareader as pdr

# %%
name = '넷마블'
x = df2.loc[name]['종목코드']
find = '{:06d}.KS'.format(x)

# %%
df_h = pdr.get_data_yahoo(find)

# %%
df1 = pd.DataFrame(data=df_h['Close'], index=df_h.index)

# %%
df1
# Out:
#                Close
# Date
# 2017-05-12  162000.0
# 2017-05-15  160000.0
# 2017-05-16  156000.0
# 2017-05-17  144000.0
# 2017-05-18  148000.0
# ...              ...
# 2020-10-19  133000.0
# 2020-10-20  135500.0
# 2020-10-21  133000.0
# 2020-10-22  127500.0
# 2020-10-23  128500.0
#
# [840 rows x 1 columns]

# %%
train = df1[:670]
test = df1[670:]

# %%
train
# Out:
#                Close
# Date
# 2017-05-12  162000.0
# 2017-05-15  160000.0
# 2017-05-16  156000.0
# 2017-05-17  144000.0
# 2017-05-18  148000.0
# ...              ...
# 2020-02-11   94100.0
# 2020-02-12   94900.0
# 2020-02-13   93400.0
# 2020-02-14   97700.0
# 2020-02-17   95700.0
#
# [670 rows x 1 columns]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
s_train = scaler.fit_transform(train)
s_test = scaler.fit_transform(test)

# %%
s_train
# Out:
# array([[0.67362924],
#        [0.6562228 ],
#        [0.62140992],
#        [0.51697128],
#        [0.55178416],
#        [0.51261967],
#        [0.4821584 ],
#        [0.51261967],
#        [0.5256745 ],
#        [0.51697128],
#        [0.49956484],
#        [0.54308094],
#        [0.56483899],
#        [0.58659704],
#        [0.58224543],
#        [0.64316797],
#        [0.66492602],
#        [0.66057441],
#        [0.59965187],
#        [0.56048738],
#        [0.49521323],
#        [0.53002611],
#        [0.50826806],
#        [0.54743255],
#        [0.58659704],
#        [0.57354221],
#        [0.59965187],
#        [0.59530026],
#        [0.58224543],
#        [0.59965187],
#        [0.59094865],
#        [0.5691906 ],
#        [0.56048738],
#        [0.6127067 ],
#        [0.6127067 ],
#        [0.59094865],
#        [0.59094865],
#        [0.56483899],
#        [0.55178416],
#        [0.6127067 ],
#        [0.57789382],
#        [0.55613577],
#        [0.5256745 ],
#        [0.5256745 ],
#        [0.53002611],
#        [0.53002611],
#        [0.5256745 ],
#        [0.5256745 ],
#        [0.55613577],
#        [0.55178416],
#        [0.56048738],
#        [0.53872933],
#        [0.53437772],
#        [0.53437772],
#        [0.52132289],
#        [0.50826806],
#        [0.49521323],
#        [0.49521323],
#        [0.45169713],
#        [0.39947781],
#        [0.43429069],
#        [0.44299391],
#        [0.43429069],
#        [0.39947781],
#        [0.37336815],
#        [0.40382942],
#        [0.45169713],
#        [0.44299391],
#        [0.46910357],
#        [0.50391645],
#        [0.52132289],
#        [0.51261967],
#        [0.61705831],
#        [0.5691906 ],
#        [0.55613577],
#        [0.53002611],
#        [0.59094865],
#        [0.60835509],
#        [0.60835509],
#        [0.60835509],
#        [0.57354221],
#        [0.63011314],
#        [0.63881636],
#        [0.57354221],
#        [0.5691906 ],
#        [0.54308094],
#        [0.56048738],
#        [0.56483899],
#        [0.57354221],
#        [0.60835509],
#        [0.60835509],
#        [0.62576153],
#        [0.62140992],
#        [0.5691906 ],
#        [0.5691906 ],
#        [0.56483899],
#        [0.55178416],
#        [0.58224543],
#        [0.58224543],
#        [0.59094865],
#        [0.56048738],
#        [0.67362924],
#        [0.66492602],
#        [0.73890339],
#        [0.79982594],
#        [0.76936466],
#        [0.77371628],
#        [0.75195822],
#        [0.80417755],
#        [0.78677111],
#        [0.79112272],
#        [0.80852916],
#        [0.74760661],
#        [0.77806789],
#        [0.76066144],
#        [0.80852916],
#        [0.78677111],
#        [0.88685814],
#        [0.87815492],
#        [0.8694517 ],
#        [0.88250653],
#        [0.9129678 ],
#        [0.87815492],
#        [0.88685814],
#        [0.93907746],
#        [0.87380331],
#        [0.86074848],
#        [0.92602263],
#        [0.87380331],
#        [0.90426458],
#        [0.88250653],
#        [0.81288077],
#        [0.82158399],
#        [0.73455178],
#        [0.85639687],
#        [0.88250653],
#        [0.85204526],
#        [0.85639687],
#        [0.84769365],
#        [0.87815492],
#        [0.89991297],
#        [0.93907746],
#        [0.99129678],
#        [1.        ],
#        [0.92602263],
#        [0.92167102],
#        [0.89991297],
#        [0.81723238],
#        [0.85639687],
#        [0.8694517 ],
#        [0.9129678 ],
#        [0.90426458],
#        [0.83899043],
#        [0.75630983],
#        [0.71279373],
#        [0.70409051],
#        [0.73020017],
#        [0.72584856],
#        [0.70844212],
#        [0.66927763],
#        [0.68668407],
#        [0.71279373],
#        [0.73020017],
#        [0.71279373],
#        [0.72149695],
#        [0.69103568],
#        [0.72149695],
#        [0.72149695],
#        [0.70409051],
#        [0.79112272],
#        [0.76066144],
#        [0.743255  ],
#        [0.77806789],
#        [0.77371628],
#        [0.73890339],
#        [0.66492602],
#        [0.59530026],
#        [0.48651001],
#        [0.48651001],
#        [0.44734552],
#        [0.50391645],
#        [0.53437772],
#        [0.50391645],
#        [0.54743255],
#        [0.51697128],
#        [0.55613577],
#        [0.58224543],
#        [0.63881636],
#        [0.64751958],
#        [0.62140992],
#        [0.54743255],
#        [0.5691906 ],
#        [0.50826806],
#        [0.51697128],
#        [0.49956484],
#        [0.5256745 ],
#        [0.58224543],
#        [0.58224543],
#        [0.55613577],
#        [0.54308094],
#        [0.54743255],
#        [0.56483899],
#        [0.53437772],
#        [0.55178416],
#        [0.56048738],
#        [0.55178416],
#        [0.50826806],
#        [0.53437772],
#        [0.53002611],
#        [0.5256745 ],
#        [0.54308094],
#        [0.59530026],
#        [0.63446475],
#        [0.64751958],
#        [0.53872933],
#        [0.53872933],
#        [0.50391645],
#        [0.50391645],
#        [0.47345518],
#        [0.47345518],
#        [0.46040035],
#        [0.46910357],
#        [0.42558747],
#        [0.42993908],
#        [0.43429069],
#        [0.39077459],
#        [0.38207137],
#        [0.37336815],
#        [0.39077459],
#        [0.40382942],
#        [0.41253264],
#        [0.49956484],
#        [0.54743255],
#        [0.55613577],
#        [0.50826806],
#        [0.44734552],
#        [0.43429069],
#        [0.4386423 ],
#        [0.4821584 ],
#        [0.4821584 ],
#        [0.50826806],
#        [0.47780679],
#        [0.49521323],
#        [0.4821584 ],
#        [0.47780679],
#        [0.49521323],
#        [0.53002611],
#        [0.54743255],
#        [0.5691906 ],
#        [0.58224543],
#        [0.63881636],
#        [0.63446475],
#        [0.63011314],
#        [0.60835509],
#        [0.63011314],
#        [0.58659704],
#        [0.60400348],
#        [0.57789382],
#        [0.57789382],
#        [0.57789382],
#        [0.58659704],
#        [0.56048738],
#        [0.55178416],
#        [0.56048738],
#        [0.55178416],
#        [0.57354221],
#        [0.61705831],
#        [0.60400348],
#        [0.63881636],
#        [0.63881636],
#        [0.60400348],
#        [0.59094865],
#        [0.56048738],
#        [0.59530026],
#        [0.64316797],
#        [0.61705831],
#        [0.62140992],
#        [0.66057441],
#        [0.68233246],
#        [0.67798085],
#        [0.71279373],
#        [0.64751958],
#        [0.5691906 ],
#        [0.56483899],
#        [0.55613577],
#        [0.53437772],
#        [0.53437772],
#        [0.55613577],
#        [0.54308094],
#        [0.56048738],
#        [0.5691906 ],
#        [0.53872933],
#        [0.49086162],
#        [0.52132289],
#        [0.53002611],
#        [0.50391645],
#        [0.50826806],
#        [0.52132289],
#        [0.51261967],
#        [0.49956484],
#        [0.36031332],
#        [0.36901654],
#        [0.32985205],
#        [0.33855527],
#        [0.27328111],
#        [0.29939077],
#        [0.28198433],
#        [0.33855527],
#        [0.30809399],
#        [0.32985205],
#        [0.33855527],
#        [0.32985205],
#        [0.29503916],
#        [0.3124456 ],
#        [0.30809399],
#        [0.27763272],
#        [0.27763272],
#        [0.29939077],
#        [0.27328111],
#        [0.25587467],
#        [0.24717145],
#        [0.25152306],
#        [0.24281984],
#        [0.26457789],
#        [0.28198433],
#        [0.27328111],
#        [0.25152306],
#        [0.22976501],
#        [0.23846823],
#        [0.28633594],
#        [0.29939077],
#        [0.29503916],
#        [0.26457789],
#        [0.27763272],
#        [0.31679721],
#        [0.30374238],
#        [0.28633594],
#        [0.32985205],
#        [0.36031332],
#        [0.36031332],
#        [0.31679721],
#        [0.25587467],
#        [0.26022628],
#        [0.23846823],
#        [0.26022628],
#        [0.25587467],
#        [0.25587467],
#        [0.24281984],
#        [0.21235857],
#        [0.20800696],
#        [0.13402959],
#        [0.06266319],
#        [0.19060052],
#        [0.23846823],
#        [0.21671018],
#        [0.26457789],
#        [0.28633594],
#        [0.27328111],
#        [0.26022628],
#        [0.27328111],
#        [0.29503916],
#        [0.32985205],
#        [0.33420366],
#        [0.3516101 ],
#        [0.32985205],
#        [0.33420366],
#        [0.34290688],
#        [0.30374238],
#        [0.32550044],
#        [0.33855527],
#        [0.3516101 ],
#        [0.36031332],
#        [0.38642298],
#        [0.41688425],
#        [0.39947781],
#        [0.36901654],
#        [0.34725849],
#        [0.35596171],
#        [0.2254134 ],
#        [0.24281984],
#        [0.1818973 ],
#        [0.16449086],
#        [0.1818973 ],
#        [0.21235857],
#        [0.18624891],
#        [0.19930374],
#        [0.20800696],
#        [0.2254134 ],
#        [0.21235857],
#        [0.26022628],
#        [0.25587467],
#        [0.22106179],
#        [0.26457789],
#        [0.23411662],
#        [0.18624891],
#        [0.16884247],
#        [0.20800696],
#        [0.2254134 ],
#        [0.21235857],
#        [0.23846823],
#        [0.25587467],
#        [0.2689295 ],
#        [0.24717145],
#        [0.23846823],
#        [0.21671018],
#        [0.21671018],
#        [0.18624891],
#        [0.16449086],
#        [0.18624891],
#        [0.19930374],
#        [0.19060052],
#        [0.22106179],
#        [0.23411662],
#        [0.2254134 ],
#        [0.22106179],
#        [0.19495213],
#        [0.21671018],
#        [0.21671018],
#        [0.29939077],
#        [0.29939077],
#        [0.29068755],
#        [0.33855527],
#        [0.34290688],
#        [0.29939077],
#        [0.30374238],
#        [0.28198433],
#        [0.26457789],
#        [0.29503916],
#        [0.29503916],
#        [0.32114883],
#        [0.32550044],
#        [0.32550044],
#        [0.29068755],
#        [0.2689295 ],
#        [0.23846823],
#        [0.24717145],
#        [0.24281984],
#        [0.24717145],
#        [0.25152306],
#        [0.25587467],
#        [0.25587467],
#        [0.2689295 ],
#        [0.30809399],
#        [0.3124456 ],
#        [0.29503916],
#        [0.28633594],
#        [0.2689295 ],
#        [0.2689295 ],
#        [0.26457789],
#        [0.31679721],
#        [0.31679721],
#        [0.34725849],
#        [0.3516101 ],
#        [0.33855527],
#        [0.3124456 ],
#        [0.35596171],
#        [0.34725849],
#        [0.34290688],
#        [0.33855527],
#        [0.33420366],
#        [0.37771976],
#        [0.3951262 ],
#        [0.41253264],
#        [0.43429069],
#        [0.44734552],
#        [0.44299391],
#        [0.41688425],
#        [0.42123586],
#        [0.44734552],
#        [0.3951262 ],
#        [0.37771976],
#        [0.35596171],
#        [0.36031332],
#        [0.36901654],
#        [0.37336815],
#        [0.36031332],
#        [0.32985205],
#        [0.32550044],
#        [0.36466493],
#        [0.33855527],
#        [0.40382942],
#        [0.38642298],
#        [0.33420366],
#        [0.29068755],
#        [0.29068755],
#        [0.28633594],
#        [0.26022628],
#        [0.25587467],
#        [0.2689295 ],
#        [0.23846823],
#        [0.25152306],
#        [0.23846823],
#        [0.24281984],
#        [0.21671018],
#        [0.24717145],
#        [0.26022628],
#        [0.30809399],
#        [0.33420366],
#        [0.34290688],
#        [0.29939077],
#        [0.32985205],
#        [0.31679721],
#        [0.32550044],
#        [0.32114883],
#        [0.36466493],
#        [0.36466493],
#        [0.36901654],
#        [0.35596171],
#        [0.36031332],
#        [0.36031332],
#        [0.39077459],
#        [0.32985205],
#        [0.32114883],
#        [0.32985205],
#        [0.24717145],
#        [0.1383812 ],
#        [0.14708442],
#        [0.13402959],
#        [0.10443864],
#        [0.10356832],
#        [0.07832898],
#        [0.12097476],
#        [0.08268059],
#        [0.10356832],
#        [0.102698  ],
#        [0.08006963],
#        [0.06179286],
#        [0.04264578],
#        [0.06527415],
#        [0.06875544],
#        [0.05570061],
#        [0.05483029],
#        [0.06092254],
#        [0.06266319],
#        [0.06092254],
#        [0.05221932],
#        [0.05221932],
#        [0.05395997],
#        [0.04786771],
#        [0.05483029],
#        [0.03220191],
#        [0.03046127],
#        [0.03481288],
#        [0.04525674],
#        [0.04699739],
#        [0.04873803],
#        [0.        ],
#        [0.05308964],
#        [0.03307224],
#        [0.03829417],
#        [0.07745866],
#        [0.07397737],
#        [0.08877285],
#        [0.08355091],
#        [0.06962576],
#        [0.07223673],
#        [0.0791993 ],
#        [0.08442124],
#        [0.08355091],
#        [0.09138381],
#        [0.09225413],
#        [0.11140122],
#        [0.10704961],
#        [0.08964317],
#        [0.102698  ],
#        [0.09747607],
#        [0.11923412],
#        [0.12532637],
#        [0.12532637],
#        [0.11836379],
#        [0.09660574],
#        [0.09660574],
#        [0.11575283],
#        [0.11662315],
#        [0.09138381],
#        [0.09399478],
#        [0.08268059],
#        [0.08616188],
#        [0.10443864],
#        [0.06788512],
#        [0.02436902],
#        [0.06092254],
#        [0.09660574],
#        [0.10095735],
#        [0.07136641],
#        [0.06527415],
#        [0.06614447],
#        [0.05047868],
#        [0.0591819 ],
#        [0.0435161 ],
#        [0.05047868],
#        [0.04873803],
#        [0.03481288],
#        [0.02088773],
#        [0.02523934],
#        [0.02175805],
#        [0.0156658 ],
#        [0.02959095],
#        [0.04612707],
#        [0.03742385],
#        [0.06266319],
#        [0.06266319],
#        [0.08268059],
#        [0.07049608],
#        [0.08181027],
#        [0.05657093],
#        [0.07049608],
#        [0.03655352],
#        [0.04699739],
#        [0.04786771],
#        [0.0278503 ],
#        [0.0278503 ],
#        [0.02088773],
#        [0.03133159],
#        [0.0435161 ],
#        [0.04873803],
#        [0.03916449],
#        [0.03829417],
#        [0.02959095],
#        [0.04177546],
#        [0.0356832 ],
#        [0.0356832 ],
#        [0.01914708],
#        [0.02872063],
#        [0.01653612],
#        [0.02262837],
#        [0.03220191],
#        [0.04003481],
#        [0.04960836],
#        [0.051349  ],
#        [0.05308964],
#        [0.04786771],
#        [0.04090513],
#        [0.04003481],
#        [0.06353351],
#        [0.06179286],
#        [0.05047868],
#        [0.04873803],
#        [0.06788512],
#        [0.04960836],
#        [0.05221932],
#        [0.0278503 ],
#        [0.03916449],
#        [0.02349869],
#        [0.03829417],
#        [0.04438642],
#        [0.10356832],
#        [0.11923412],
#        [0.12445605],
#        [0.11749347],
#        [0.09225413],
#        [0.0870322 ],
#        [0.07832898],
#        [0.08268059],
#        [0.102698  ],
#        [0.06353351],
#        [0.05657093],
#        [0.03742385],
#        [0.0435161 ],
#        [0.05308964],
#        [0.06353351],
#        [0.05221932],
#        [0.08529156],
#        [0.07745866],
#        [0.08093995],
#        [0.08268059],
#        [0.08964317],
#        [0.07658834],
#        [0.11401218],
#        [0.09660574]])

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=64
generator = TimeseriesGenerator(s_train, s_train, length, batch_size=1)

# %%
generator[0]
# Out:
# (array([[[0.67362924],
#          [0.6562228 ],
#          [0.62140992],
#          [0.51697128],
#          [0.55178416],
#          [0.51261967],
#          [0.4821584 ],
#          [0.51261967],
#          [0.5256745 ],
#          [0.51697128],
#          [0.49956484],
#          [0.54308094],
#          [0.56483899],
#          [0.58659704],
#          [0.58224543],
#          [0.64316797],
#          [0.66492602],
#          [0.66057441],
#          [0.59965187],
#          [0.56048738],
#          [0.49521323],
#          [0.53002611],
#          [0.50826806],
#          [0.54743255],
#          [0.58659704],
#          [0.57354221],
#          [0.59965187],
#          [0.59530026],
#          [0.58224543],
#          [0.59965187],
#          [0.59094865],
#          [0.5691906 ],
#          [0.56048738],
#          [0.6127067 ],
#          [0.6127067 ],
#          [0.59094865],
#          [0.59094865],
#          [0.56483899],
#          [0.55178416],
#          [0.6127067 ],
#          [0.57789382],
#          [0.55613577],
#          [0.5256745 ],
#          [0.5256745 ],
#          [0.53002611],
#          [0.53002611],
#          [0.5256745 ],
#          [0.5256745 ],
#          [0.55613577],
#          [0.55178416],
#          [0.56048738],
#          [0.53872933],
#          [0.53437772],
#          [0.53437772],
#          [0.52132289],
#          [0.50826806],
#          [0.49521323],
#          [0.49521323],
#          [0.45169713],
#          [0.39947781],
#          [0.43429069],
#          [0.44299391],
#          [0.43429069],
#          [0.39947781]]]), array([[0.37336815]]))

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.LSTM(32, input_shape=(64,1)))
model.add(tf.keras.layers.Dense(1))

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(generator, epochs=3)
# Out:
# Epoch 1/3
# 606/606 [==============================] - 2s 4ms/step - loss: 0.0045
# Epoch 2/3
# 606/606 [==============================] - 3s 4ms/step - loss: 0.0026
# Epoch 3/3
# 606/606 [==============================] - 3s 4ms/step - loss: 0.0020

# %%
t_generator = TimeseriesGenerator(s_test, s_test, length, batch_size=1)

# %%
pred = model.predict(t_generator)

# %%
true_pred = scaler.inverse_transform(pred)

# %%
test2 = test.drop(test.index[0:length])

# %%
test2
# Out:
#                Close
# Date
# 2020-05-22   94300.0
# 2020-05-25   96800.0
# 2020-05-26   97300.0
# 2020-05-27   98600.0
# 2020-05-28   94800.0
# ...              ...
# 2020-10-19  133000.0
# 2020-10-20  135500.0
# 2020-10-21  133000.0
# 2020-10-22  127500.0
# 2020-10-23  128500.0
#
# [106 rows x 1 columns]

# %%
test2['pred'] = true_pred

# %%
test2
# Out:
#                Close           pred
# Date
# 2020-05-22   94300.0   95748.523438
# 2020-05-25   96800.0   95344.156250
# 2020-05-26   97300.0   95811.187500
# 2020-05-27   98600.0   96389.867188
# 2020-05-28   94800.0   97242.164062
# ...              ...            ...
# 2020-10-19  133000.0  141589.796875
# 2020-10-20  135500.0  137465.265625
# 2020-10-21  133000.0  135777.015625
# 2020-10-22  127500.0  134123.312500
# 2020-10-23  128500.0  131360.375000
#
# [106 rows x 2 columns]

# %%
plt.plot(test2.index, test2.Close)
plt.plot(test2.index, test2.pred)

# %%
batch = s_test[-length:]
c_batch = batch.reshape(1, length, 1)
forecast = []
for i in range(365):
  c_pred = model.predict(c_batch)[0]
  forecast.append(c_pred)
  c_batch = np.append(c_batch[:,1:,:], [[c_pred]], axis=1) # numpy 다루기 다시 확인
  forecast_inv = scaler.inverse_transform(forecast)

# %%
forecast_idx = np.linspace(0, 1, 365) * (np.datetime64('2021-10-24') - np.datetime64('2020-10-24')) + np.datetime64('2020-10-24')

# %%
plt.figure(figsize=(20,10))

plt.plot(test)
plt.plot(forecast_idx, forecast_inv)
plt.xlabel('Date')
plt.ylabel('price')

plt.xticks(rotation='45')
# Out:
# (array([737485., 737546., 737607., 737669., 737730., 737791., 737850.,
#         737911., 737972., 738034., 738095.]),
#  <a list of 11 Text major ticklabel objects>)
