# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.1'

# %%
from tensorflow import keras

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import numpy as np

# %%
# AND
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_data = np.array([[0], [0], [0], [1]])

# %%
model = keras.Sequential()

# %% [markdown]
# *   항목 추가
# *   항목 추가

# %%
# x_data.shape
model.add(keras.layers.Dense(1, activation='sigmoid', input_shape=(2,)))

# %%
optimizer = keras.optimizers.SGD(lr=0.1)

# %%
model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=['accuracy'])

# %%
model.fit(x_data, y_data, batch_size=4, epochs=1000 )
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 997us/step - loss: 0.7428 - accuracy: 0.7500
# Epoch 2/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.7394 - accuracy: 0.7500
# Epoch 3/1000
# 1/1 [==============================] - 0s 0s/step - loss: 0.7360 - accuracy: 0.7500
# Epoch 4/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.7327 - accuracy: 0.7500
# Epoch 5/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.7294 - accuracy: 0.7500
# Epoch 6/1000
# 1/1 [==============================] - 0s 997us/step - loss: 0.7262 - accuracy: 0.7500
# Epoch 7/1000
# 1/1 [==============================] - 0s 0s/step - loss: 0.7230 - accuracy: 0.7500
# Epoch 8/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7198 - accuracy: 0.7500
# Epoch 9/1000
# 1/1 [==============================] - 0s 997us/step - loss: 0.7166 - accuracy: 0.7500
# Epoch 10/1000
# ...

# %%
np.round(model.predict(x_data))
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %% [markdown]
# gpu 드라이버(최신버전) -> cuda(10.1) -> cuDNN(10.1) -> tensorflow(pip)(2.3)
